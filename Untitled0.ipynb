# %%
import yfinance as yf #collect data from yfinance
import pandas as pd #data analysis
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns #data visualisation

# %%
start_date = '2025-01-01'
end_date = '2025-10-01'

# %%
baba = yf.download('9988.HK', start_date, end_date)
# Out:
# /tmp/ipython-input-3483202252.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   baba = yf.download('9988.HK', start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
baba
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker         9988.HK     9988.HK     9988.HK     9988.HK    9988.HK
# Date
# 2025-01-02   81.128914   82.525962   80.629966   82.226597   48562393
# 2025-01-03   82.426178   83.573759   81.827442   82.925126   57859265
# 2025-01-06   81.977127   83.174599   81.727653   82.975023   36259231
# 2025-01-07   81.228706   82.276492   80.330599   81.977128   57807719
# 2025-01-08   80.729759   82.076917   80.230811   81.428283   51033856
# ...                ...         ...         ...         ...        ...
# 2025-09-24  174.000000  174.899994  157.600006  158.500000  261023658
# 2025-09-25  172.000000  177.800003  171.100006  174.000000  172333447
# 2025-09-26  166.500000  171.899994  165.000000  168.399994  152987253
# 2025-09-29  173.399994  174.300003  166.899994  166.899994  134259119
# 2025-09-30  177.000000  178.000000  173.699997  176.600006  135460219
#
# [185 rows x 5 columns]

# %%
Tesla = yf.download('TSLA', start_date, end_date)
# Out:
# /tmp/ipython-input-1284809003.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Tesla = yf.download('TSLA', start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
Tesla
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2025-01-02  379.279999  392.730011  373.040009  390.100006  109710700
# 2025-01-03  410.440002  411.880005  379.450012  381.480011   95423300
# 2025-01-06  411.049988  426.429993  401.700012  423.200012   85516500
# 2025-01-07  394.359985  414.329987  390.000000  405.829987   75699500
# 2025-01-08  394.940002  402.500000  387.399994  392.950012   73038800
# ...                ...         ...         ...         ...        ...
# 2025-09-24  442.790009  444.209991  429.029999  429.829987   93133600
# 2025-09-25  423.390015  435.350006  419.079987  435.239990   96746400
# 2025-09-26  440.399994  440.470001  421.019989  428.299988  101628200
# 2025-09-29  443.209991  450.980011  439.500000  444.350006   79491500
# 2025-09-30  444.720001  445.000000  433.119995  441.519989   74358000
#
# [186 rows x 5 columns]

# %%
BYND = yf.download('BYND', start_date, end_date)
# Out:
# /tmp/ipython-input-2900879577.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   BYND = yf.download('BYND', start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
BYND
# Out:
# Price      Close  High   Low  Open    Volume
# Ticker      BYND  BYND  BYND  BYND      BYND
# Date
# 2025-01-02  3.85  4.00  3.79  3.84   3317400
# 2025-01-03  4.01  4.08  3.83  3.93   3051800
# 2025-01-06  3.91  4.16  3.86  4.05   4257400
# 2025-01-07  3.76  4.02  3.72  3.96   2869900
# 2025-01-08  3.60  3.79  3.60  3.71   2947500
# ...          ...   ...   ...   ...       ...
# 2025-09-24  2.90  2.99  2.76  2.82   2181300
# 2025-09-25  2.83  2.89  2.73  2.84   2471500
# 2025-09-26  2.85  2.89  2.78  2.83   1256700
# 2025-09-29  1.82  2.22  1.23  1.27  65310400
# 2025-09-30  1.89  1.93  1.66  1.81  13954100
#
# [186 rows x 5 columns]

# %%
XIAOMI = yf.download('XIACY', start_date, end_date)
# Out:
# /tmp/ipython-input-1185375842.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   XIAOMI = yf.download('XIACY', start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
XIAOMI
# Out:
# Price           Close       High        Low       Open  Volume
# Ticker          XIACY      XIACY      XIACY      XIACY   XIACY
# Date
# 2025-01-02  21.830000  21.952000  21.830000  21.940001  198400
# 2025-01-03  23.546000  23.600000  23.000000  23.400000  267800
# 2025-01-06  23.344999  23.850000  23.250000  23.850000  329100
# 2025-01-07  21.893999  22.709999  21.840000  22.200001  239000
# 2025-01-08  20.910000  21.000000  20.700001  20.980000  251800
# ...               ...        ...        ...        ...     ...
# 2025-09-24  36.410000  36.520000  35.970001  36.340000  564800
# 2025-09-25  37.980000  38.070000  37.750000  37.849998  788100
# 2025-09-26  35.500000  35.730000  35.150002  35.279999  732600
# 2025-09-29  34.520000  34.750000  34.500000  34.750000  586500
# 2025-09-30  34.759998  34.779999  34.599998  34.750000  212100
#
# [186 rows x 5 columns]

# %%
XIAOMI.head()#5 rows
# Out:
# Price           Close       High        Low       Open  Volume
# Ticker          XIACY      XIACY      XIACY      XIACY   XIACY
# Date
# 2025-01-02  21.830000  21.952000  21.830000  21.940001  198400
# 2025-01-03  23.546000  23.600000  23.000000  23.400000  267800
# 2025-01-06  23.344999  23.850000  23.250000  23.850000  329100
# 2025-01-07  21.893999  22.709999  21.840000  22.200001  239000
# 2025-01-08  20.910000  21.000000  20.700001  20.980000  251800

# %%
BTC = yf.download('BTC-USD', start_date, end_date)
# Out:
# /tmp/ipython-input-576987935.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   BTC = yf.download('BTC-USD', start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2025-01-01   94419.757812   94929.867188   92788.125000   93425.101562
# 2025-01-02   96886.875000   97739.820312   94201.570312   94416.289062
# 2025-01-03   98107.429688   98956.914062   96034.617188   96881.726562
# 2025-01-04   98236.226562   98734.429688   97562.976562   98106.992188
# 2025-01-05   98314.960938   98813.304688   97291.765625   98233.906250
# ...                   ...            ...            ...            ...
# 2025-09-26  109712.828125  110359.195312  108728.976562  109041.296875
# 2025-09-27  109681.945312  109778.500000  109144.296875  109707.140625
# 2025-09-28  112122.640625  112375.484375  109236.945312  109681.945312
# 2025-09-29  114400.382812  114473.570312  111589.953125  112117.875000
# 2025-09-30  114056.085938  114836.617188  112740.562500  114396.523438
#
# Price            Volume
# ...

# %%
HANGSENG = yf.download('^HSI', start_date, end_date)
# Out:
# /tmp/ipython-input-3299270739.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   HANGSENG = yf.download('^HSI', start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
HANGSENG
# Out:
# Price              Close          High           Low          Open      Volume
# Ticker              ^HSI          ^HSI          ^HSI          ^HSI        ^HSI
# Date
# 2025-01-02  19623.320312  19932.800781  19542.980469  19932.800781  4033400000
# 2025-01-03  19760.269531  19891.859375  19634.070312  19708.740234  3393800000
# 2025-01-06  19688.289062  19851.550781  19627.839844  19848.710938  2465700000
# 2025-01-07  19447.580078  19668.650391  19252.609375  19501.449219  3581000000
# 2025-01-08  19279.839844  19483.589844  19111.539062  19390.759766  3232400000
# ...                  ...           ...           ...           ...         ...
# 2025-09-24  26518.650391  26562.880859  26057.259766  26073.689453  3023200000
# 2025-09-25  26484.679688  26640.529297  26403.519531  26536.130859  3687000000
# 2025-09-26  26128.199219  26406.050781  26072.929688  26272.300781  3440600000
# 2025-09-29  26622.880859  26687.720703  26321.570312  26321.570312  3502800000
# ...

# %%
HANGSENG.head()
# Out:
# Price              Close          High           Low          Open      Volume
# Ticker              ^HSI          ^HSI          ^HSI          ^HSI        ^HSI
# Date
# 2025-01-02  19623.320312  19932.800781  19542.980469  19932.800781  4033400000
# 2025-01-03  19760.269531  19891.859375  19634.070312  19708.740234  3393800000
# 2025-01-06  19688.289062  19851.550781  19627.839844  19848.710938  2465700000
# 2025-01-07  19447.580078  19668.650391  19252.609375  19501.449219  3581000000
# 2025-01-08  19279.839844  19483.589844  19111.539062  19390.759766  3232400000

# %%
HANGSENG.to_csv('HANGSENG.csv')

# %%
XIAOMI.to_csv('XIAOMI.csv')

# %%
Tesla.to_csv('Tesla.csv')

# %%
baba.to_csv('BABA.csv')

# %%
baba.columns
# Out:
# MultiIndex([( 'Close', 'BABA'),
#             (  'High', 'BABA'),
#             (   'Low', 'BABA'),
#             (  'Open', 'BABA'),
#             ('Volume', 'BABA')],
#            names=['Price', 'Ticker'])

# %%
baba['Close'].plot(figsize = (16,8))
plt.xlabel('date')
plt.ylabel('$price')
plt.title('baba stock price')
# Out:
# Text(0.5, 1.0, 'baba stock price')

# %%
st = yf.download('0020.HK', start_date, end_date)
# Out:
# /tmp/ipython-input-3983845255.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   st = yf.download('0020.HK', start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
st
# Out:
# Price        Close    High     Low    Open      Volume
# Ticker     0020.HK 0020.HK 0020.HK 0020.HK     0020.HK
# Date
# 2025-01-02    1.41    1.49    1.41    1.49   445155342
# 2025-01-03    1.33    1.43    1.33    1.42   675163550
# 2025-01-06    1.33    1.38    1.32    1.34   341436000
# 2025-01-07    1.33    1.34    1.26    1.31   760391069
# 2025-01-08    1.31    1.34    1.28    1.33   249315476
# ...            ...     ...     ...     ...         ...
# 2025-09-24    2.73    2.74    2.58    2.66   837268685
# 2025-09-25    2.73    2.87    2.71    2.78  1514729182
# 2025-09-26    2.62    2.75    2.61    2.72   784581533
# 2025-09-29    2.74    2.81    2.61    2.62  1013139724
# 2025-09-30    2.89    2.90    2.76    2.77  1042156229
#
# [185 rows x 5 columns]

# %%
st.columns
# Out:
# MultiIndex([( 'Close', '0020.HK'),
#             (  'High', '0020.HK'),
#             (   'Low', '0020.HK'),
#             (  'Open', '0020.HK'),
#             ('Volume', '0020.HK')],
#            names=['Price', 'Ticker'])

# %%
st['Close'].plot(figsize = (16,8))
plt.xlabel('date')
plt.ylabel('$price')
plt.title('st stock price')
plt.savefig('pic.png')

# %%
tickers = ['9988.HK', 'XIACY', 'BABA']
protfolio = yf.download(tickers, start_date, end_date)
# Out:
# /tmp/ipython-input-4027395334.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   protfolio = yf.download(tickers, start_date, end_date)
# [*********************100%***********************]  3 of 3 completed

# %%
close = protfolio['Close']

# %%
protfolio['Close'].plot(figsize = (16,8))
# Out:
# <Axes: xlabel='Date'>

# %%
protfolio['Close'].pct_change().corr()
# Out:
# /tmp/ipython-input-3692785308.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   protfolio['Close'].pct_change().corr()
# Ticker    9988.HK      BABA     XIACY
# Ticker
# 9988.HK  1.000000  0.450660  0.288369
# BABA     0.450660  1.000000  0.534681
# XIACY    0.288369  0.534681  1.000000

# %%
corrMatrix = protfolio['Close'].pct_change().corr()
sns.heatmap(corrMatrix,annot = True)
# Out:
# /tmp/ipython-input-2000422878.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   corrMatrix = protfolio['Close'].pct_change().corr()
# <Axes: xlabel='Ticker', ylabel='Ticker'>
